# %% [markdown]
# # Movie Recommendation System — Exploratory Data Analysis
# This notebook walks through the data, visualises distributions, and validates preprocessing.

# %%
import sys, os
sys.path.insert(0, os.path.join(os.getcwd(), '..'))

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.dpi'] = 100

from data_preprocessing import load_and_prepare, EDA

movie_df, ratings_df, movies_raw = load_and_prepare()

# %%
# ---- EDA summary -----------------------------------------------------------
stats = EDA.summarize(movies_raw, ratings_df)
for k, v in stats.items():
    print(f'{k:40s}: {v}')

# %%
# ---- Rating distribution ---------------------------------------------------
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

ratings_df['rating'].value_counts().sort_index().plot(kind='bar', ax=axes[0], color='steelblue')
axes[0].set_title('Rating Distribution')
axes[0].set_xlabel('Rating')
axes[0].set_ylabel('Count')

ratings_df.groupby('userId')['rating'].count().plot(kind='hist', bins=40, ax=axes[1], color='coral')
axes[1].set_title('Ratings per User')
axes[1].set_xlabel('Number of Ratings')
axes[1].set_ylabel('Users')

plt.tight_layout()
plt.show()

# %%
# ---- Genre distribution ----------------------------------------------------
genre_counts = EDA.genre_distribution(movies_raw)
genre_counts.plot(kind='barh', figsize=(10, 6), color='mediumpurple')
plt.title('Movies per Genre')
plt.xlabel('Number of Movies')
plt.tight_layout()
plt.show()

# %%
# ---- Top 20 most-rated movies ----------------------------------------------
top20 = movie_df.nlargest(20, 'num_ratings')[['title', 'genres', 'avg_rating', 'num_ratings']]
print(top20.to_string(index=False))
